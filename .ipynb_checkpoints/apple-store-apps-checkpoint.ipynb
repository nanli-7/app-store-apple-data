# %%
import pandas

# %% [markdown]
# ## Introduction of the dataset
# https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps

# %%
apps = pandas.read_csv('AppleStore.csv')

# %%
apps.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
apps.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
apps.isna().sum()
# Out:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %% [markdown]
# ## average rating for each primary genre group

# %%
# number of apps in each genre group
apps.prime_genre.value_counts()
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %%
# average user rating for each group
apps.groupby('prime_genre').user_rating.mean().sort_values(ascending=False)
# Out:
# prime_genre
# Productivity         4.005618
# Music                3.978261
# Photo & Video        3.800860
# Business             3.745614
# Health & Fitness     3.700000
# Games                3.685008
# Weather              3.597222
# Shopping             3.540984
# Reference            3.453125
# Travel               3.376543
# Education            3.376380
# Medical              3.369565
# Utilities            3.278226
# Entertainment        3.246729
# Food & Drink         3.182540
# Social Networking    2.985030
# Sports               2.982456
# News                 2.980000
# Lifestyle            2.805556
# Navigation           2.684783
# Book                 2.477679
# Finance              2.432692
# Catalogs             2.100000
# Name: user_rating, dtype: float64

# %%
# average number of rating for each group
apps.groupby('prime_genre').rating_count_tot.mean().sort_values(ascending=False)
# Out:
# prime_genre
# Social Networking    45498.898204
# Music                28842.021739
# Reference            22410.843750
# Weather              22181.027778
# Shopping             18615.327869
# Photo & Video        14352.280802
# Travel               14129.444444
# Sports               14026.929825
# Food & Drink         13938.619048
# Games                13691.996634
# News                 13015.066667
# Navigation           11853.956522
# Finance              11047.653846
# Health & Fitness      9913.172222
# Productivity          8051.325843
# Entertainment         7533.678505
# Utilities             6863.822581
# Lifestyle             6161.763889
# Book                  5125.437500
# Business              4788.087719
# Education             2239.229581
# Catalogs              1732.500000
# Medical                592.782609
# Name: rating_count_tot, dtype: float64

# %%
## rating count descriptive statistcs in each genre
apps.groupby('prime_genre').rating_count_tot.describe()
# Out:
#                     count          mean            std  min     25%    50%  \
# prime_genre
# Book                112.0   5125.437500   27733.547345  0.0    0.00    5.0
# Business             57.0   4788.087719    8967.641106  0.0  100.00  896.0
# Catalogs             10.0   1732.500000    4138.260538  0.0    0.00  106.5
# Education           453.0   2239.229581   11545.817944  0.0   13.00   77.0
# Entertainment       535.0   7533.678505   28772.537014  0.0   38.00  278.0
# Finance             104.0  11047.653846   37653.527102  0.0    0.00   17.0
# Food & Drink         63.0  13938.619048   52847.086318  0.0    6.00  148.0
# Games              3862.0  13691.996634   70486.998727  0.0   39.00  342.5
# Health & Fitness    180.0   9913.172222   48890.656742  0.0   48.75  446.5
# Lifestyle           144.0   6161.763889   32461.475006  0.0    5.75  125.5
# Medical              23.0    592.782609     924.972872  0.0    9.00   91.0
# Music               138.0  28842.021739  128775.079970  0.0  124.75  678.5
# Navigation           46.0  11853.956522   55178.047352  0.0    0.00   33.5
# News                 75.0  13015.066667   46109.786371  0.0   23.50  233.0
# Photo & Video       349.0  14352.280802  118580.717924  0.0   88.00  807.0
# Productivity        178.0   8051.325843   21835.615592  0.0   91.50  684.5
# Reference            64.0  22410.843750  125077.627598  0.0   13.25  379.5
# Shopping            122.0  18615.327869   51220.016755  0.0   41.25  960.5
# Social Networking   167.0  45498.898204  249317.381210  0.0   14.00  542.0
# Sports              114.0  14026.929825   41030.851498  0.0   29.25  169.5
# Travel               81.0  14129.444444   57637.843985  0.0   35.00  248.0
# Utilities           248.0   6863.822581   34563.544108  0.0   28.00  261.5
# Weather              72.0  22181.027778   70604.585300  0.0   29.50  334.0
#
#                         75%        max
# prime_genre
# Book                  79.00   252076.0
# Business            3292.00    38681.0
# Catalogs            1089.50    13345.0
# Education            609.00   162701.0
# Entertainment       2287.00   308844.0
# Finance             1092.25   233270.0
# Food & Drink        1428.50   303856.0
# Games               3091.50  2130805.0
# Health & Fitness    3781.25   507706.0
# Lifestyle           1160.50   342969.0
# Medical              857.50     3483.0
# Music               4949.75  1126879.0
# Navigation           858.25   345046.0
# News                3064.00   354058.0
# Photo & Video       4142.00  2161558.0
# Productivity        6280.25   161065.0
# Reference           4431.25   985920.0
# Shopping           12376.00   417779.0
# Social Networking  12027.50  2974676.0
# Sports              3807.25   290996.0
# Travel              1482.00   446185.0
# Utilities           1637.50   479440.0
# Weather             3576.75   495626.0

# %% [markdown]
# ## popular apps

# %%
# top 10 popular apps
# apps.rating_count_tot.sort_values().tail(10)
apps.nlargest(10, 'rating_count_tot')[['track_name','prime_genre','rating_count_tot',"user_rating"]]
# Out:
#                    track_name        prime_genre  rating_count_tot  \
# 16                   Facebook  Social Networking           2974676
# 519                 Instagram      Photo & Video           2161558
# 1346           Clash of Clans              Games           2130805
# 707                Temple Run              Games           1724546
# 7     Pandora - Music & Radio              Music           1126879
# 755                 Pinterest  Social Networking           1061624
# 4                       Bible          Reference            985920
# 1493         Candy Crush Saga              Games            961794
# 178             Spotify Music              Music            878563
# 275               Angry Birds              Games            824451
#
#       user_rating
# 16            3.5
# 519           4.5
# 1346          4.5
# 707           4.5
# 7             4.0
# 755           4.5
# 4             4.5
# 1493          4.5
# 178           4.5
# 275           4.5

# %%
#apps.groupby('prime_genre').rating_count_tot.max().sort_values()
#apps.groupby('prime_genre').apply(pandas.DataFrame.sort_values, 'rating_count_tot', ascending=False)
top_apps = apps.groupby('prime_genre').apply(lambda x: x[x["rating_count_tot"] == x["rating_count_tot"].max()])
top_apps[['track_name','prime_genre','rating_count_tot',"user_rating"]].sort_values(by='rating_count_tot', ascending=False)
# Out:
#                                                                track_name  \
# prime_genre
# Social Networking 16                                             Facebook
# Photo & Video     519                                           Instagram
# Games             1346                                     Clash of Clans
# Music             7                               Pandora - Music & Radio
# Reference         4                                                 Bible
# Health & Fitness  265      Calorie Counter & Diet Tracker by MyFitnessPal
# Weather           53        The Weather Channel: Forecast, Radar & Alerts
# Utilities         12                 Google – Search made just for mobile
# Travel            45                                         Google Earth
# Shopping          317    Groupon - Deals, Coupons & Discount Shopping App
# News              221                                             Twitter
# Navigation        174     Waze - GPS Navigation, Maps & Real-time Traffic
# Lifestyle         127      Zillow Real Estate - Homes for Sale & for Rent
# Entertainment     358                                             Netflix
# Food & Drink      209                                           Starbucks
# Sports            150   ESPN: Get scores, news, alerts & watch live sp...
# Book              82          Kindle – Read eBooks, Magazines & Textbooks
# Finance           67                                        Chase Mobile℠
# Education         1597          Duolingo - Learn Spanish, French and more
# Productivity      1                             Evernote - stay organized
# Business          123                                   Indeed Job Search
# Catalogs          3347      CPlus for Craigslist app - mobile classifieds
# Medical           187                         Baby Connect (Activity Log)
#
#                               prime_genre  rating_count_tot  user_rating
# prime_genre
# Social Networking 16    Social Networking           2974676          3.5
# Photo & Video     519       Photo & Video           2161558          4.5
# Games             1346              Games           2130805          4.5
# Music             7                 Music           1126879          4.0
# Reference         4             Reference            985920          4.5
# Health & Fitness  265    Health & Fitness            507706          4.5
# Weather           53              Weather            495626          3.5
# Utilities         12            Utilities            479440          3.5
# Travel            45               Travel            446185          3.5
# Shopping          317            Shopping            417779          4.5
# News              221                News            354058          3.5
# Navigation        174          Navigation            345046          4.5
# Lifestyle         127           Lifestyle            342969          4.5
# Entertainment     358       Entertainment            308844          3.5
# Food & Drink      209        Food & Drink            303856          4.5
# Sports            150              Sports            290996          3.5
# Book              82                 Book            252076          3.5
# Finance           67              Finance            233270          4.5
# Education         1597          Education            162701          4.5
# Productivity      1          Productivity            161065          4.0
# Business          123            Business             38681          4.0
# Catalogs          3347           Catalogs             13345          5.0
# Medical           187             Medical              3483          4.5
